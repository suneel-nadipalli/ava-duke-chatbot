# %%
from datasets import load_dataset

dataset = load_dataset("suneeln-duke/duke_qac_v3")
# Out:
# Downloading readme:   0%|          | 0.00/442 [00:00<?, ?B/s]
# Downloading data: 100%|██████████| 1.16M/1.16M [00:00<00:00, 3.38MB/s]
# Downloading data: 100%|██████████| 309k/309k [00:00<00:00, 1.20MB/s]
# Generating train split:   0%|          | 0/559 [00:00<?, ? examples/s]
# Generating val split:   0%|          | 0/140 [00:00<?, ? examples/s]

# %%
sample = dataset['val'][1]

context = sample['Context']

question = sample['Question']

answer = sample['Answer']

# %%
# %%time

import requests

API_URL = "https://z42ydp6bpbh9juql.us-east-1.aws.endpoints.huggingface.cloud"
headers = {
	"Accept" : "application/json",
	"Authorization": "Bearer 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",
	"Content-Type": "application/json" 
}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()

output = query({
    "inputs": "",
    "question": question,
    "context": context,
    "temp": 0.3,
    "max_tokens": 200
})
# Out:
# CPU times: user 18.2 ms, sys: 3.74 ms, total: 21.9 ms
# Wall time: 22.4 s

# %%
question
# Out:
# 'Could you provide more details about the class meeting schedules mentioned in the text?'

# %%
output
# Out:
# 'The class meeting schedules for AIPI courses at Duke University are as follows: 1. Each course typically meets once per week for 2 hours and 45 minutes. 2. Students are expected to come to class in-person for the Fall 2021 semester, unless they are unable to travel or obtain a visa due to the COVID-19 pandemic. 3. Classes will be offered both in-person and online for the Fall 2021 semester. 4. Students who will be physically located in Durham, NC, USA, for the semester are expected to come to class in-person. 5. The Drop/Add period for Fall 2021 classes ends on September 3, 2021. 6. Students may make changes to their schedule up to this date. 7. The classes begin on August 23, 2021, for the Fall'

# %%
answer
# Out:
# 'DukeList serves as a valuable platform for enhancing communication within the Duke University community, particularly for topics related to housing, roommates, and ride-sharing. Here are some ways in which DukeList facilitates communication in these areas:\n\n1. **Housing Listings**: DukeList allows students, faculty, and staff to post housing listings, making it easier for individuals to find available housing options both on and off-campus. This helps in connecting those seeking accommodation with those offering housing solutions.\n\n2. **Roommate Search**: For individuals looking for roommates, DukeList provides a platform to post roommate requests or browse through listings of others looking for roommates. This feature enables students to find compatible roommates to share accommodations with.\n\n3. **Ride-Sharing Opportunities**: DukeList also serves as a space where individuals can post ride-sharing opportunities or requests. This can be particularly useful for students who are looking to carpool or share transportation to and from campus, events, or other destinations.\n\n4. **Community Engagement**: By facilitating discussions and interactions related to housing, roommates, and ride-sharing, DukeList helps in fostering a sense of community within the Duke University ecosystem. It encourages collaboration and mutual support among members of the community.\n\n5. **Timely Updates**: Since some positions, housing listings, or ride-sharing opportunities may arise closer to the start of the semester, DukeList provides a platform for real-time communication and updates. This ensures that individuals are informed about the latest opportunities available within the Duke community.\n\nIn summary, DukeList plays a crucial role in connecting members of the Duke University community for various purposes, including housing, roommates, and ride-sharing, thereby enhancing communication and collaboration among students, faculty, and staff.'
